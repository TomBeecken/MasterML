# %%
import datetime
import itertools
import os
from pathlib import Path

from stanfordnlp.server import CoreNLPClient

import global_options
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 import os
#       4 from pathlib import Path
# ----> 6 from stanfordnlp.server import CoreNLPClient
#       8 import global_options
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/stanfordnlp/server/__init__.py:1
# ----> 1 from stanfordnlp.protobuf import to_text
#       2 from stanfordnlp.protobuf import Document, Sentence, Token, IndexedWord, Span
#       3 from stanfordnlp.protobuf import ParseTree, DependencyGraph, CorefChain
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/stanfordnlp/protobuf/__init__.py:7
#       5 from google.protobuf.internal.encoder import _EncodeVarint
#       6 from google.protobuf.internal.decoder import _DecodeVarint
# ----> 7 from .CoreNLP_pb2 import *
# ...
